# %% [markdown]
# Paste in the url in your copy-buffer, then click run on each of the cells to download and view the data:

# %%
#@title Paste url

here = "" #@param {type:"string"}

print(here)

# %%
# %load_ext google.colab.data_table
def read_file(url):
    "can be a url, will call pd read_.. for the ext type"
    import pandas as pd
    import os
    st=os.path.splitext(fn)
    ft=st[-1]
    if ft=='.tsv':
        df=pd.read_csv(fn, sep='\t')
    elif ft=='.csv':
        df=pd.read_csv(fn)
    else:
        df="no reader, can !wget the file"
    return df
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %%
#some example filenames:
#fn="https://darchive.mblwhoilibrary.org/bitstream/1912/26532/1/dataset-752737_bergen-mesohux-2017-dissolved-nutrients__v1.tsv"
#fn2="https://darchive.mblwhoilibrary.org/bitstream/1912/23805/1/dataset-753388_hhq-chlorophyll__v1.tsv"
df1=read_file(here)

# %%
df1
# Out:
#             Treatment Bag  ...  Ammonium_uM Orthophosphate_uM
# 0             Ambient   1  ...           nd                nd
# 1             Ambient   1  ...           nd                nd
# 2             Ambient   1  ...           nd                nd
# 3             Ambient   1  ...           nd                nd
# 4             Ambient   1  ...           nd                nd
# ..                ...  ..  ...          ...               ...
# 421  Redfield; Shaded  11  ...           bd             0.123
# 422  Redfield; Shaded  11  ...           bd             0.199
# 423  Redfield; Shaded  11  ...           bd             0.205
# 424  Redfield; Shaded  11  ...        0.459             0.141
# 425  Redfield; Shaded  11  ...           bd             0.133
#
# [426 rows x 8 columns]
